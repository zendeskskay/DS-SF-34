# %% [markdown]
# ### Data Wrangling: Storms and Severe Weather Events

# %%
import os

import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 100)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 100)

from sklearn import preprocessing, neighbors, model_selection

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv('dataset-06-storms.csv.gz', low_memory=False)

# %%
df.head()
# Out:
#    STATE__            BGN_DATE BGN_TIME TIME_ZONE  COUNTY COUNTYNAME STATE  \
# 0        1   4/18/1950 0:00:00      130       CST      97     MOBILE    AL
# 1        1   4/18/1950 0:00:00      145       CST       3    BALDWIN    AL
# 2        1   2/20/1951 0:00:00     1600       CST      57    FAYETTE    AL
# 3        1    6/8/1951 0:00:00      900       CST      89    MADISON    AL
# 4        1  11/15/1951 0:00:00     1500       CST      43    CULLMAN    AL
#
#     EVTYPE  BGN_RANGE BGN_AZI BGN_LOCATI END_DATE END_TIME  COUNTY_END  \
# 0  TORNADO          0     NaN        NaN      NaN      NaN           0
# 1  TORNADO          0     NaN        NaN      NaN      NaN           0
# 2  TORNADO          0     NaN        NaN      NaN      NaN           0
# 3  TORNADO          0     NaN        NaN      NaN      NaN           0
# 4  TORNADO          0     NaN        NaN      NaN      NaN           0
#
#    COUNTYENDN  END_RANGE END_AZI END_LOCATI  LENGTH  WIDTH  F  MAG  \
# 0         NaN          0     NaN        NaN    14.0    100  3    0
# 1         NaN          0     NaN        NaN     2.0    150  2    0
# 2         NaN          0     NaN        NaN     0.1    123  2    0
# 3         NaN          0     NaN        NaN     0.0    100  2    0
# 4         NaN          0     NaN        NaN     0.0    150  2    0
#
#    FATALITIES  INJURIES  PROPDMG PROPDMGEXP  CROPDMG CROPDMGEXP  WFO  \
# 0           0        15     25.0          K        0        NaN  NaN
# 1           0         0      2.5          K        0        NaN  NaN
# 2           0         2     25.0          K        0        NaN  NaN
# 3           0         2      2.5          K        0        NaN  NaN
# 4           0         2      2.5          K        0        NaN  NaN
#
#   STATEOFFIC ZONENAMES  LATITUDE  LONGITUDE  LATITUDE_E  LONGITUDE_ REMARKS  \
# 0        NaN       NaN      3040       8812        3051        8806     NaN
# 1        NaN       NaN      3042       8755           0           0     NaN
# 2        NaN       NaN      3340       8742           0           0     NaN
# 3        NaN       NaN      3458       8626           0           0     NaN
# 4        NaN       NaN      3412       8642           0           0     NaN
#
#    REFNUM
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5

# %%
df.shape
# Out:
# (902297, 37)

# %%
df.COUNTYENDN.isnull().sum()
# Out:
# 902297

# %%
df.isnull().sum().sort_values()
# Out:
# STATE__            0
# LONGITUDE_         0
# LONGITUDE          0
# CROPDMG            0
# PROPDMG            0
# INJURIES           0
# FATALITIES         0
# MAG                0
# WIDTH              0
# END_RANGE          0
# COUNTY_END         0
# LENGTH             0
# COUNTY             0
# BGN_DATE           0
# BGN_TIME           0
# TIME_ZONE          0
# STATE              0
# EVTYPE             0
# BGN_RANGE          0
# REFNUM             0
# LATITUDE_E        40
# LATITUDE          47
# COUNTYNAME      1589
# WFO           142069
# END_TIME      238978
# END_DATE      243411
# STATEOFFIC    248769
# REMARKS       287433
# BGN_LOCATI    287743
# PROPDMGEXP    465934
# END_LOCATI    499225
# BGN_AZI       547332
# ZONENAMES     594029
# CROPDMGEXP    618413
# END_AZI       724837
# F             843563
# COUNTYENDN    902297
# dtype: int64

# %%
#dropping COUNTYENDN due to all NULLs 
#dropping REMARKS due to not learning natural language processing yet
#dropping COUNTY_END all 0
#df = df.drop(['COUNTYENDN','REMARKS','COUNTY_END'], axis=1)
#dropping the very specific location info, not helpful for identifying patterns
#df = df.drop(['LATITUDE','LONGITUDE','LATITUDE_E','LONGITUDE_'], axis=1)

# %%
df1 = df[['EVTYPE','FATALITIES','INJURIES','PROPDMG','CROPDMG','PROPDMGEXP','CROPDMGEXP']]

# %%
df1.describe()
# Out:
#           FATALITIES       INJURIES        PROPDMG        CROPDMG
# count  902297.000000  902297.000000  902297.000000  902297.000000
# mean        0.016785       0.155745      12.063101       1.527022
# std         0.765283       5.431887      59.475851      22.173680
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.500000       0.000000
# max       583.000000    1700.000000    5000.000000     990.000000

# %%
df1.PROPDMGEXP.unique()
# Out:
# array(['K', 'M', nan, 'B', 'm', '+', '0', '5', '6', '?', '4', '2', '3',
#        'h', '7', 'H', '-', '1', '8'], dtype=object)

# %%
df1.PROPDMG *= df1.PROPDMGEXP.map({'M'or'm': 1. / 1000, 'K': 1., 'B': 1. / 1000000})

# %%
df1.PROPDMG *= df1.PROPDMGEXP.map({exponent_to_multiplier})

# %%
df1.CROPDMGEXP.unique()
# Out:
# array([nan, 'M', 'K', 'm', 'B', '?', '0', 'k', '2'], dtype=object)

# %%
df1.CROPDMG *= df1.CROPDMGEXP.map({'M'or'm': 1. / 1000, 'K'or'k': 1., 'B': 1. / 1000000})

# %%
df1
# Out:
#                 EVTYPE  FATALITIES  INJURIES   PROPDMG  CROPDMG PROPDMGEXP  \
# 0              TORNADO           0        15   25.0000      NaN          K
# 1              TORNADO           0         0    2.5000      NaN          K
# 2              TORNADO           0         2   25.0000      NaN          K
# 3              TORNADO           0         2    2.5000      NaN          K
# 4              TORNADO           0         2    2.5000      NaN          K
# 5              TORNADO           0         6    2.5000      NaN          K
# 6              TORNADO           0         1    2.5000      NaN          K
# 7              TORNADO           0         0    2.5000      NaN          K
# 8              TORNADO           1        14   25.0000      NaN          K
# 9              TORNADO           0         0   25.0000      NaN          K
# 10             TORNADO           0         3    0.0025      NaN          M
# 11             TORNADO           0         3    0.0025      NaN          M
# 12             TORNADO           1        26  250.0000      NaN          K
# 13             TORNADO           0        12    0.0000      NaN          K
# 14             TORNADO           0         6   25.0000      NaN          K
# 15             TORNADO           4        50   25.0000      NaN          K
# 16             TORNADO           0         2   25.0000      NaN          K
# 17             TORNADO           0         0   25.0000      NaN          K
# 18             TORNADO           0         0   25.0000      NaN          K
# 19             TORNADO           0         0   25.0000      NaN          K
# 20             TORNADO           0         0   25.0000      NaN          K
# 21             TORNADO           0         0    2.5000      NaN          K
# 22             TORNADO           0         0    2.5000      NaN          K
# 23             TORNADO           0         1   25.0000      NaN          K
# 24             TORNADO           0         1   25.0000      NaN          K
# 25             TORNADO           1         8   25.0000      NaN          K
# 26             TORNADO           0         2   25.0000      NaN          K
# 27             TORNADO           0         1   25.0000      NaN          K
# 28             TORNADO           0         6   25.0000      NaN          K
# 29             TORNADO           0         2    2.5000      NaN          K
# 30             TORNADO           0         0    2.5000      NaN          K
# 31             TORNADO           0        12    2.5000      NaN          K
# 32             TORNADO           0         0   25.0000      NaN          K
# 33             TORNADO           6       195    0.0025      NaN          M
# 34             TORNADO           0         2   25.0000      NaN          K
# 35             TORNADO           7        12  250.0000      NaN          K
# 36             TORNADO           0         0    2.5000      NaN          K
# 37             TORNADO           2         3   25.0000      NaN          K
# 38             TORNADO           0         2    2.5000      NaN          K
# 39             TORNADO           0         0   25.0000      NaN          K
# 40             TORNADO           0         0    2.5000      NaN          K
# 41             TORNADO           0         1   25.0000      NaN          K
# 42             TORNADO           0         0    2.5000      NaN          K
# 43             TORNADO           0         0   25.0000      NaN          K
# 44             TORNADO           0         0   25.0000      NaN          K
# 45             TORNADO           0         0    0.0300      NaN          K
# 46             TORNADO           0         1   25.0000      NaN          K
# 47             TORNADO           0         4  250.0000      NaN          K
# 48             TORNADO           0        26  250.0000      NaN          K
# 49             TORNADO           0         3    2.5000      NaN          K
# ...                ...         ...       ...       ...      ...        ...
# 902247  WINTER WEATHER           0         0    5.0000        0          K
# 902248    WINTER STORM           0         0    2.0000        0          K
# 902249    WINTER STORM           0         0    5.0000        0          K
# 902250       HIGH WIND           0         0    0.0000        0          K
# 902251       HIGH WIND           0         0    0.0000        0          K
# 902252    WINTER STORM           0         0    0.0000        0          K
# 902253         DROUGHT           0         0    0.0000        0          K
# 902254     STRONG WIND           0         0    0.6000        0          K
# 902255       DENSE FOG           0         0    0.0000        0          K
# 902256     STRONG WIND           0         0    1.0000        0          K
# 902257         DROUGHT           0         0    0.0000        0          K
# 902258         DROUGHT           0         0    2.0000        0          K
# 902259       HIGH WIND           0         0    7.5000        0          K
# 902260       HIGH WIND           0         0    0.0000        0          K
# 902261       HIGH WIND           0         0    0.0000        0          K
# 902262       HIGH WIND           0         0    0.0000        0          K
# 902263       HIGH WIND           0         0    0.0000        0          K
# 902264       HIGH WIND           0         0    0.0000        0          K
# 902265    WINTER STORM           0         0    0.0000        0          K
# 902266         DROUGHT           0         0    0.0000        0          K
# 902267         DROUGHT           0         0    0.0000        0          K
# 902268       HIGH WIND           0         0    0.0000        0          K
# 902269    WINTER STORM           0         0    0.0000        0          K
# 902270    WINTER STORM           0         0    0.0000        0          K
# 902271    WINTER STORM           0         0    0.0000        0          K
# 902272       DENSE FOG           0         0    0.0000        0          K
# 902273       DENSE FOG           0         0    0.0000        0          K
# 902274       DENSE FOG           0         0    0.0000        0          K
# 902275       DENSE FOG           0         0    0.0000        0          K
# 902276       DENSE FOG           0         0    0.0000        0          K
# 902277       DENSE FOG           0         0    0.0000        0          K
# 902278      HEAVY SNOW           0         0    0.0000        0          K
# 902279    WINTER STORM           0         0    0.0000        0          K
# 902280        BLIZZARD           0         0    0.0000        0          K
# 902281    WINTER STORM           0         0    0.0000        0          K
# 902282        BLIZZARD           0         0    0.0000        0          K
# 902283       HIGH WIND           0         0    0.0000        0          K
# 902284      HEAVY SNOW           0         0    0.0000        0          K
# 902285       HIGH WIND           0         0    0.0000        0          K
# 902286         DROUGHT           0         0    0.0000        0          K
# 902287  WINTER WEATHER           0         0    0.0000        0          K
# 902288    FROST/FREEZE           0         0    0.0000        0          K
# 902289       HIGH WIND           0         0    0.0000        0          K
# 902290  WINTER WEATHER           0         0    0.0000        0          K
# 902291  WINTER WEATHER           0         0    0.0000        0          K
# 902292       HIGH WIND           0         0    0.0000        0          K
# 902293       HIGH WIND           0         0    0.0000        0          K
# 902294       HIGH WIND           0         0    0.0000        0          K
# 902295        BLIZZARD           0         0    0.0000        0          K
# 902296      HEAVY SNOW           0         0    0.0000        0          K
#
#        CROPDMGEXP
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# 28            NaN
# 29            NaN
# 30            NaN
# 31            NaN
# 32            NaN
# 33            NaN
# 34            NaN
# 35            NaN
# 36            NaN
# 37            NaN
# 38            NaN
# 39            NaN
# 40            NaN
# 41            NaN
# 42            NaN
# 43            NaN
# 44            NaN
# 45            NaN
# 46            NaN
# 47            NaN
# 48            NaN
# 49            NaN
# ...           ...
# 902247          K
# 902248          K
# 902249          K
# 902250          K
# 902251          K
# 902252          K
# 902253          K
# 902254          K
# 902255          K
# 902256          K
# 902257          K
# 902258          K
# 902259          K
# 902260          K
# 902261          K
# 902262          K
# 902263          K
# 902264          K
# 902265          K
# 902266          K
# 902267          K
# 902268          K
# 902269          K
# 902270          K
# 902271          K
# 902272          K
# 902273          K
# 902274          K
# 902275          K
# 902276          K
# 902277          K
# 902278          K
# 902279          K
# 902280          K
# 902281          K
# 902282          K
# 902283          K
# 902284          K
# 902285          K
# 902286          K
# 902287          K
# 902288          K
# 902289          K
# 902290          K
# 902291          K
# 902292          K
# 902293          K
# 902294          K
# 902295          K
# 902296          K
#
# [902297 rows x 7 columns]

# %%
exponent_to_multiplier = {
    #allll combinations
}

# %% [markdown]
# ## drop all the rows that don't have a fatality, injury, property or crop damage

# %%
#get rid of all the storms have no injuries and no damage and no deaths
#df[df.gender == 'Female']
df2 = df1[(df1.FATALITIES > 0) | (df1.INJURIES > 0) | (df1.PROPDMG > 0) | (df1.CROPDMG > 0)]

# %%
df2.sort_values('FATALITIES')
# Out:
#                             EVTYPE  FATALITIES  INJURIES     PROPDMG  \
# 0                          TORNADO           0        15   25.000000
# 629408                 FLASH FLOOD           0         0   25.000000
# 629409                 FLASH FLOOD           0         0   25.000000
# 629410           THUNDERSTORM WIND           0         0   10.000000
# 629411           THUNDERSTORM WIND           0         0    1.000000
# 629412           THUNDERSTORM WIND           0         0    1.000000
# 629413           THUNDERSTORM WIND           0         0    1.000000
# 629414           THUNDERSTORM WIND           0         0    1.000000
# 629415           THUNDERSTORM WIND           0         0   25.000000
# 629416                 FLASH FLOOD           0         0   10.000000
# 629417                 FLASH FLOOD           0         0   10.000000
# 629418                 FLASH FLOOD           0         0   20.000000
# 629419                 FLASH FLOOD           0         0   10.000000
# 629407                 FLASH FLOOD           0         0   25.000000
# 629420           THUNDERSTORM WIND           0         0   15.000000
# 629422           THUNDERSTORM WIND           0         0    2.000000
# 629423           THUNDERSTORM WIND           0         0    5.000000
# 629424           THUNDERSTORM WIND           0         0    2.000000
# 629425           THUNDERSTORM WIND           0         0    1.000000
# 629426           THUNDERSTORM WIND           0         0   10.000000
# 629427                 FLASH FLOOD           0         0   20.000000
# 629428                 FLASH FLOOD           0         0   25.000000
# 629430           THUNDERSTORM WIND           0         0    2.000000
# 629433                 FLASH FLOOD           0         0   15.000000
# 629434           THUNDERSTORM WIND           0         0    2.000000
# 629436           THUNDERSTORM WIND           0         0    3.000000
# 629437                 FLASH FLOOD           0         0   10.000000
# 629421                 FLASH FLOOD           0         0   10.000000
# 629406                 FLASH FLOOD           0         0    5.000000
# 629405                 FLASH FLOOD           0         0   10.000000
# 629404                 FLASH FLOOD           0         0   10.000000
# 629278                   TSTM WIND           0         0         NaN
# 629279                   TSTM WIND           0         0   25.000000
# 629285                        HAIL           0         0    4.000000
# 629286                   TSTM WIND           0         0    8.000000
# 629325                 STRONG WIND           0         0   50.000000
# 629329            LAKE-EFFECT SNOW           0         0    0.002000
# 629330            LAKE-EFFECT SNOW           0         0  750.000000
# 629331            LAKE-EFFECT SNOW           0         0  100.000000
# 629332            LAKE-EFFECT SNOW           0         0    0.020000
# 629337                       FLOOD           0         0   50.000000
# 629338              WINTER WEATHER           0         0    5.000000
# 629339              WINTER WEATHER           0         0    5.000000
# 629340              WINTER WEATHER           0         0   10.000000
# 629341              WINTER WEATHER           0         0    5.000000
# 629370                   HIGH WIND           0         0   10.000000
# 629371                   HIGH WIND           0         0    5.000000
# 629381            LAKE-EFFECT SNOW           0         0    8.000000
# 629394           THUNDERSTORM WIND           0         0    1.000000
# 629395           THUNDERSTORM WIND           0         0    5.000000
# ...                            ...         ...       ...         ...
# 301426              EXCESSIVE HEAT          24        60         NaN
# 635600              EXCESSIVE HEAT          24        40         NaN
# 29549                      TORNADO          24       410  250.000000
# 611802              EXCESSIVE HEAT          24         0         NaN
# 314264                     TORNADO          25       145    0.050000
# 195000  TORNADOES, TSTM WIND, HAIL          25         0    0.000002
# 93                         TORNADO          25       200    0.002500
# 79091                      TORNADO          25       342    0.002500
# 231041                   HEAT WAVE          25         0         NaN
# 153748                     TORNADO          26       500    0.250000
# 198522                        HEAT          27         0         NaN
# 859831                     TORNADO          27         0    0.050000
# 305523                     TORNADO          27        12    0.040000
# 230927   UNSEASONABLY WARM AND DRY          29         0         NaN
# 6376                       TORNADO          29       180    0.002500
# 33832                      TORNADO          29       350    0.250000
# 164824                     TORNADO          30       121    0.002500
# 565387              EXCESSIVE HEAT          30         0         NaN
# 79092                      TORNADO          30       411    0.000000
# 58093                      TORNADO          31       257    0.002500
# 35121                      TORNADO          31       252    0.000000
# 35110                      TORNADO          31       252    0.000000
# 785238                     TSUNAMI          32       129    0.081000
# 310081                     TORNADO          32       258    0.200000
# 343500              EXCESSIVE HEAT          32         0         NaN
# 231042                   HEAT WAVE          33         0         NaN
# 29565                      TORNADO          33       500    0.025000
# 365760              EXCESSIVE HEAT          33         0         NaN
# 7244                       TORNADO          34       350   25.000000
# 116010                     TORNADO          36      1150    0.250000
# 83577                      TORNADO          37       176    0.002500
# 78122                      TORNADO          38       270    0.025000
# 629241              EXCESSIVE HEAT          42         0         NaN
# 362849              EXCESSIVE HEAT          42       397         NaN
# 157884                     TORNADO          42      1700    0.250000
# 860385                     TORNADO          44       800    0.000002
# 606362              EXCESSIVE HEAT          46        18  170.000000
# 598499              EXCESSIVE HEAT          49         0         NaN
# 6369                       TORNADO          50       325    0.002500
# 78566                      TORNADO          57       504    0.025000
# 247937                EXTREME HEAT          57         0         NaN
# 230926              EXCESSIVE HEAT          67         0         NaN
# 371111              EXCESSIVE HEAT          74       135         NaN
# 46308                      TORNADO          75       270  250.000000
# 67883                      TORNADO          90      1228    0.250000
# 355127              EXCESSIVE HEAT          99         0         NaN
# 148851                     TORNADO         114       597    0.025000
# 68669                      TORNADO         116       785    0.025000
# 862633                     TORNADO         158      1150    0.000003
# 198703                        HEAT         583         0         NaN
#
#          CROPDMG PROPDMGEXP CROPDMGEXP
# 0            NaN          K        NaN
# 629408    0.0000          K          K
# 629409    0.0000          K          K
# 629410    0.0000          K          K
# 629411    0.0000          K          K
# 629412    0.0000          K          K
# 629413    0.0000          K          K
# 629414    0.0000          K          K
# 629415    0.0000          K          K
# 629416    0.0000          K          K
# 629417    0.0000          K          K
# 629418    0.0000          K          K
# 629419    0.0000          K          K
# 629407    0.0000          K          K
# 629420    0.0000          K          K
# 629422    0.0000          K          K
# 629423    0.0000          K          K
# 629424    0.0000          K          K
# 629425    0.0000          K          K
# 629426    0.0000          K          K
# 629427    0.0000          K          K
# 629428    0.0000          K          K
# 629430    0.0000          K          K
# 629433    0.0000          K          K
# 629434    0.0000          K          K
# 629436    0.0000          K          K
# 629437    0.0000          K          K
# 629421    0.0000          K          K
# 629406    0.0000          K          K
# 629405    0.0000          K          K
# 629404    0.0000          K          K
# 629278  100.0000        NaN          K
# 629279       NaN          K        NaN
# 629285       NaN          K        NaN
# 629286       NaN          K        NaN
# 629325       NaN          K        NaN
# 629329    0.0000          M          K
# 629330    0.0000          K          K
# 629331    0.0000          K          K
# 629332    0.0000          M          K
# 629337    0.0000          K          K
# 629338    0.0000          K          K
# 629339    0.0000          K          K
# 629340    0.0000          K          K
# 629341    0.0000          K          K
# 629370    0.0000          K          K
# 629371    0.0000          K          K
# 629381    0.0000          K          K
# 629394    0.0000          K          K
# 629395    0.0000          K          K
# ...          ...        ...        ...
# 301426       NaN        NaN        NaN
# 635600       NaN        NaN        NaN
# 29549        NaN          K        NaN
# 611802       NaN        NaN        NaN
# 314264       NaN          M        NaN
# 195000    0.0025          B          M
# 93           NaN          M        NaN
# 79091        NaN          M        NaN
# 231041       NaN        NaN        NaN
# 153748       NaN          M        NaN
# 198522       NaN        NaN        NaN
# 859831    0.0000          M          K
# 305523  100.0000          M          K
# 230927       NaN        NaN        NaN
# 6376         NaN          M        NaN
# 33832        NaN          M        NaN
# 164824       NaN          M        NaN
# 565387       NaN        NaN        NaN
# 79092        NaN          K        NaN
# 58093        NaN          M        NaN
# 35121        NaN          K        NaN
# 35110        NaN          K        NaN
# 785238   20.0000          M          K
# 310081    0.0022          M          M
# 343500       NaN        NaN        NaN
# 231042       NaN        NaN        NaN
# 29565        NaN          M        NaN
# 365760       NaN        NaN        NaN
# 7244         NaN          K        NaN
# 116010       NaN          M        NaN
# 83577        NaN          M        NaN
# 78122        NaN          M        NaN
# 629241       NaN        NaN        NaN
# 362849       NaN        NaN        NaN
# 157884       NaN          M        NaN
# 860385    0.0000          B          K
# 606362    0.4924          K          M
# 598499       NaN        NaN        NaN
# 6369         NaN          M        NaN
# 78566        NaN          M        NaN
# 247937       NaN        NaN        NaN
# 230926       NaN        NaN        NaN
# 371111       NaN        NaN        NaN
# 46308        NaN          K        NaN
# 67883        NaN          M        NaN
# 355127       NaN        NaN        NaN
# 148851       NaN          M        NaN
# 68669        NaN          M        NaN
# 862633    0.0000          B          K
# 198703       NaN        NaN        NaN
#
# [254319 rows x 7 columns]

# %% [markdown]
# ## Deal with EVTYPE

# %%
df1.EVTYPE.unique()
# Out:
# array(['TORNADO', 'TSTM WIND', 'HAIL', 'ICE STORM/FLASH FLOOD',
#        'WINTER STORM', 'HURRICANE OPAL/HIGH WINDS', 'THUNDERSTORM WINDS',
#        'HURRICANE ERIN', 'HURRICANE OPAL', 'HEAVY RAIN', 'LIGHTNING',
#        'THUNDERSTORM WIND', 'DENSE FOG', 'RIP CURRENT',
#        'THUNDERSTORM WINS', 'FLASH FLOODING', 'FLASH FLOOD', 'TORNADO F0',
#        'THUNDERSTORM WINDS LIGHTNING', 'THUNDERSTORM WINDS/HAIL', 'HEAT',
#        'HIGH WINDS', 'WIND', 'HEAVY RAINS', 'LIGHTNING AND HEAVY RAIN',
#        'THUNDERSTORM WINDS HAIL', 'COLD', 'HEAVY RAIN/LIGHTNING',
#        'FLASH FLOODING/THUNDERSTORM WI', 'FLOODING', 'WATERSPOUT',
#        'EXTREME COLD', 'LIGHTNING/HEAVY RAIN', 'HIGH WIND', 'FREEZE',
#        'RIVER FLOOD', 'HIGH WINDS HEAVY RAINS', 'AVALANCHE',
#        'MARINE MISHAP', 'HIGH WIND/SEAS', 'HIGH WINDS/HEAVY RAIN',
#        'HIGH SEAS', 'COASTAL FLOOD', 'SEVERE TURBULENCE',
#        'RECORD RAINFALL', 'HEAVY SNOW', 'HEAVY SNOW/WIND', 'DUST STORM',
#        'FLOOD', 'APACHE COUNTY', 'SLEET', 'DUST DEVIL', 'ICE STORM',
#        'EXCESSIVE HEAT', 'THUNDERSTORM WINDS/FUNNEL CLOU', 'GUSTY WINDS',
#        'HEAVY SURF COASTAL FLOODING', 'HIGH SURF', 'WILD FIRES', 'HIGH',
#        'WINTER STORM HIGH WINDS', 'WINTER STORMS', 'MUDSLIDES',
#        'RAINSTORM', 'SEVERE THUNDERSTORM', 'SEVERE THUNDERSTORMS',
#        'SEVERE THUNDERSTORM WINDS', 'THUNDERSTORMS WINDS',
#        'FLOOD/FLASH FLOOD', 'FLOOD/RAIN/WINDS', 'THUNDERSTORMS', 'WINDS',
#        'FUNNEL CLOUD', 'HIGH WIND DAMAGE', 'STRONG WIND', 'HEAVY SNOWPACK',
#        'FLASH FLOOD/', 'HEAVY SURF', 'DRY MIRCOBURST WINDS',
#        'DRY MICROBURST', 'URBAN FLOOD', 'THUNDERSTORM WINDSS',
#        'MICROBURST WINDS', 'HEAT WAVE', 'UNSEASONABLY WARM',
#        'COASTAL FLOODING', 'STRONG WINDS', 'BLIZZARD',
#        'WATERSPOUT/TORNADO', 'WATERSPOUT TORNADO', 'STORM SURGE',
#        'URBAN/SMALL STREAM FLOOD', 'WATERSPOUT-',
#        'TORNADOES, TSTM WIND, HAIL', 'TROPICAL STORM ALBERTO',
#        'TROPICAL STORM', 'TROPICAL STORM GORDON', 'TROPICAL STORM JERRY',
#        'LIGHTNING THUNDERSTORM WINDS', 'URBAN FLOODING', 'MINOR FLOODING',
#        'WATERSPOUT-TORNADO', 'LIGHTNING INJURY',
#        'LIGHTNING AND THUNDERSTORM WIN', 'FLASH FLOODS',
#        'THUNDERSTORM WINDS53', 'WILDFIRE', 'DAMAGING FREEZE',
#        'THUNDERSTORM WINDS 13', 'HURRICANE', 'SNOW', 'LIGNTNING', 'FROST',
#        'FREEZING RAIN/SNOW', 'HIGH WINDS/', 'THUNDERSNOW', 'FLOODS',
#        'COOL AND WET', 'HEAVY RAIN/SNOW', 'GLAZE ICE', 'MUD SLIDE',
#        'HIGH  WINDS', 'RURAL FLOOD', 'MUD SLIDES', 'EXTREME HEAT',
#        'DROUGHT', 'COLD AND WET CONDITIONS', 'EXCESSIVE WETNESS',
#        'SLEET/ICE STORM', 'GUSTNADO', 'FREEZING RAIN',
#        'SNOW AND HEAVY SNOW', 'GROUND BLIZZARD', 'EXTREME WIND CHILL',
#        'MAJOR FLOOD', 'SNOW/HEAVY SNOW', 'FREEZING RAIN/SLEET',
#        'ICE JAM FLOODING', 'COLD AIR TORNADO', 'WIND DAMAGE', 'FOG',
#        'TSTM WIND 55', 'SMALL STREAM FLOOD', 'THUNDERTORM WINDS',
#        'HAIL/WINDS', 'SNOW AND ICE', 'WIND STORM', 'GRASS FIRES',
#        'LAKE FLOOD', 'HAIL/WIND', 'WIND/HAIL', 'ICE', 'SNOW AND ICE STORM',
#        'THUNDERSTORM  WINDS', 'WINTER WEATHER', 'DROUGHT/EXCESSIVE HEAT',
#        'THUNDERSTORMS WIND', 'TUNDERSTORM WIND',
#        'URBAN AND SMALL STREAM FLOODIN', 'THUNDERSTORM WIND/LIGHTNING',
#        'HEAVY RAIN/SEVERE WEATHER', 'THUNDERSTORM', 'WATERSPOUT/ TORNADO',
#        'LIGHTNING.', 'HURRICANE-GENERATED SWELLS',
#        'RIVER AND STREAM FLOOD', 'HIGH WINDS/COASTAL FLOOD', 'RAIN',
#        'RIVER FLOODING', 'ICE FLOES', 'LIGHTNING FIRE', 'HEAVY LAKE SNOW',
#        'RECORD COLD', 'HEAVY SNOW/FREEZING RAIN', 'COLD WAVE',
#        'DUST DEVIL WATERSPOUT', 'TORNADO F3', 'TORNDAO',
#        'FLOOD/RIVER FLOOD', 'MUD SLIDES URBAN FLOODING', 'TORNADO F1',
#        'GLAZE/ICE STORM', 'GLAZE', 'HEAVY SNOW/WINTER STORM', 'MICROBURST',
#        'AVALANCE', 'BLIZZARD/WINTER STORM', 'DUST STORM/HIGH WINDS',
#        'ICE JAM', 'FOREST FIRES', 'FROST\\FREEZE', 'THUNDERSTORM WINDS.',
#        'HVY RAIN', 'HAIL 150', 'HAIL 075', 'HAIL 100',
#        'THUNDERSTORM WIND G55', 'HAIL 125', 'THUNDERSTORM WIND G60',
#        'THUNDERSTORM WINDS G60', 'HARD FREEZE', 'HAIL 200',
#        'HEAVY SNOW AND HIGH WINDS', 'HEAVY SNOW/HIGH WINDS & FLOOD',
#        'HEAVY RAIN AND FLOOD', 'RIP CURRENTS/HEAVY SURF',
#        'URBAN AND SMALL', 'WILDFIRES', 'FOG AND COLD TEMPERATURES',
#        'SNOW/COLD', 'FLASH FLOOD FROM ICE JAMS', 'TSTM WIND G58',
#        'MUDSLIDE', 'HEAVY SNOW SQUALLS', 'SNOW SQUALL', 'SNOW/ICE STORM',
#        'HEAVY SNOW/SQUALLS', 'HEAVY SNOW-SQUALLS', 'ICY ROADS',
#        'HEAVY MIX', 'SNOW FREEZING RAIN', 'SNOW/SLEET',
#        'SNOW/FREEZING RAIN', 'SNOW SQUALLS', 'SNOW/SLEET/FREEZING RAIN',
#        'RECORD SNOW', 'HAIL 0.75', 'RECORD HEAT',
#        'THUNDERSTORM WIND 65MPH', 'THUNDERSTORM WIND/ TREES',
#        'THUNDERSTORM WIND/AWNING', 'THUNDERSTORM WIND 98 MPH',
#        'THUNDERSTORM WIND TREES', 'TORNADO F2', 'RIP CURRENTS',
#        'HURRICANE EMILY', 'COASTAL SURGE', 'HURRICANE GORDON',
#        'HURRICANE FELIX', 'THUNDERSTORM WIND 60 MPH',
#        'THUNDERSTORM WINDS 63 MPH', 'THUNDERSTORM WIND/ TREE',
#        'THUNDERSTORM DAMAGE TO', 'THUNDERSTORM WIND 65 MPH',
#        'FLASH FLOOD - HEAVY RAIN', 'THUNDERSTORM WIND.',
#        'FLASH FLOOD/ STREET', 'BLOWING SNOW', 'HEAVY SNOW/BLIZZARD',
#        'THUNDERSTORM HAIL', 'THUNDERSTORM WINDSHAIL', 'LIGHTNING  WAUSEON',
#        'THUDERSTORM WINDS', 'ICE AND SNOW', 'STORM FORCE WINDS',
#        'HEAVY SNOW/ICE', 'LIGHTING', 'HIGH WIND/HEAVY SNOW',
#        'THUNDERSTORM WINDS AND', 'HEAVY PRECIPITATION',
#        'HIGH WIND/BLIZZARD', 'TSTM WIND DAMAGE', 'FLOOD FLASH',
#        'RAIN/WIND', 'SNOW/ICE', 'HAIL 75', 'HEAT WAVE DROUGHT',
#        'HEAVY SNOW/BLIZZARD/AVALANCHE', 'HEAT WAVES',
#        'UNSEASONABLY WARM AND DRY', 'UNSEASONABLY COLD',
#        'RECORD/EXCESSIVE HEAT', 'THUNDERSTORM WIND G52', 'HIGH WAVES',
#        'FLASH FLOOD/FLOOD', 'FLOOD/FLASH', 'LOW TEMPERATURE',
#        'HEAVY RAINS/FLOODING', 'THUNDERESTORM WINDS',
#        'THUNDERSTORM WINDS/FLOODING', 'HYPOTHERMIA', 'THUNDEERSTORM WINDS',
#        'THUNERSTORM WINDS', 'HIGH WINDS/COLD', 'COLD/WINDS',
#        'SNOW/ BITTER COLD', 'COLD WEATHER', 'RAPIDLY RISING WATER',
#        'WILD/FOREST FIRE', 'ICE/STRONG WINDS', 'SNOW/HIGH WINDS',
#        'HIGH WINDS/SNOW', 'SNOWMELT FLOODING',
#        'HEAVY SNOW AND STRONG WINDS', 'SNOW ACCUMULATION', 'SNOW/ ICE',
#        'SNOW/BLOWING SNOW', 'TORNADOES', 'THUNDERSTORM WIND/HAIL',
#        'FREEZING DRIZZLE', 'HAIL 175', 'FLASH FLOODING/FLOOD', 'HAIL 275',
#        'HAIL 450', 'EXCESSIVE RAINFALL', 'THUNDERSTORMW', 'HAILSTORM',
#        'TSTM WINDS', 'TSTMW', 'TSTM WIND 65)', 'TROPICAL STORM DEAN',
#        'THUNDERSTORM WINDS/ FLOOD', 'LANDSLIDE', 'HIGH WIND AND SEAS',
#        'THUNDERSTORMWINDS', 'WILD/FOREST FIRES', 'HEAVY SEAS',
#        'HAIL DAMAGE', 'FLOOD & HEAVY RAIN', '?', 'THUNDERSTROM WIND',
#        'FLOOD/FLASHFLOOD', 'HIGH WATER', 'HIGH WIND 48', 'LANDSLIDES',
#        'URBAN/SMALL STREAM', 'BRUSH FIRE', 'HEAVY SHOWER', 'HEAVY SWELLS',
#        'URBAN SMALL', 'URBAN FLOODS', 'FLASH FLOOD/LANDSLIDE',
#        'HEAVY RAIN/SMALL STREAM URBAN', 'FLASH FLOOD LANDSLIDES',
#        'TSTM WIND/HAIL', 'Other', 'Ice jam flood (minor', 'Tstm Wind',
#        'URBAN/SML STREAM FLD', 'ROUGH SURF', 'Heavy Surf', 'Dust Devil',
#        'Marine Accident', 'Freeze', 'Strong Wind', 'COASTAL STORM',
#        'Erosion/Cstl Flood', 'River Flooding', 'Damaging Freeze',
#        'Beach Erosion', 'High Surf', 'Heavy Rain/High Surf',
#        'Unseasonable Cold', 'Early Frost', 'Wintry Mix', 'Extreme Cold',
#        'Coastal Flooding', 'Torrential Rainfall', 'Landslump',
#        'Hurricane Edouard', 'Coastal Storm', 'TIDAL FLOODING',
#        'Tidal Flooding', 'Strong Winds', 'EXTREME WINDCHILL', 'Glaze',
#        'Extended Cold', 'Whirlwind', 'Heavy snow shower', 'Light snow',
#        'Light Snow', 'MIXED PRECIP', 'Freezing Spray', 'DOWNBURST',
#        'Mudslides', 'Microburst', 'Mudslide', 'Cold', 'Coastal Flood',
#        'Snow Squalls', 'Wind Damage', 'Light Snowfall', 'Freezing Drizzle',
#        'Gusty wind/rain', 'GUSTY WIND/HVY RAIN', 'Wind',
#        'Cold Temperature', 'Heat Wave', 'Snow', 'COLD AND SNOW',
#        'RAIN/SNOW', 'TSTM WIND (G45)', 'Gusty Winds', 'GUSTY WIND',
#        'TSTM WIND 40', 'TSTM WIND 45', 'TSTM WIND (41)', 'TSTM WIND (G40)',
#        'Frost/Freeze', 'AGRICULTURAL FREEZE', 'OTHER',
#        'Hypothermia/Exposure', 'HYPOTHERMIA/EXPOSURE', 'Lake Effect Snow',
#        'Freezing Rain', 'Mixed Precipitation', 'BLACK ICE', 'COASTALSTORM',
#        'LIGHT SNOW', 'DAM BREAK', 'Gusty winds', 'blowing snow',
#        'GRADIENT WIND', 'TSTM WIND AND LIGHTNING', 'gradient wind',
#        'Gradient wind', 'Freezing drizzle', 'WET MICROBURST',
#        'Heavy surf and wind', 'TYPHOON', 'HIGH SWELLS', 'SMALL HAIL',
#        'UNSEASONAL RAIN', 'COASTAL FLOODING/EROSION', ' TSTM WIND (G45)',
#        'TSTM WIND  (G45)', 'HIGH WIND (G40)', 'TSTM WIND (G35)',
#        'COASTAL EROSION', 'SEICHE', 'COASTAL  FLOODING/EROSION',
#        'HYPERTHERMIA/EXPOSURE', 'WINTRY MIX', 'ROCK SLIDE',
#        'GUSTY WIND/HAIL', ' TSTM WIND', 'LANDSPOUT', 'EXCESSIVE SNOW',
#        'LAKE EFFECT SNOW', 'FLOOD/FLASH/FLOOD', 'MIXED PRECIPITATION',
#        'WIND AND WAVE', 'LIGHT FREEZING RAIN', 'ICE ROADS', 'ROUGH SEAS',
#        'TSTM WIND G45', 'NON-SEVERE WIND DAMAGE', 'WARM WEATHER',
#        'THUNDERSTORM WIND (G40)', ' FLASH FLOOD', 'LATE SEASON SNOW',
#        'WINTER WEATHER MIX', 'ROGUE WAVE', 'FALLING SNOW/ICE',
#        'NON-TSTM WIND', 'NON TSTM WIND', 'BLOWING DUST', 'VOLCANIC ASH',
#        '   HIGH SURF ADVISORY', 'HAZARDOUS SURF', 'WHIRLWIND',
#        'ICE ON ROAD', 'DROWNING', 'EXTREME COLD/WIND CHILL',
#        'MARINE TSTM WIND', 'HURRICANE/TYPHOON', 'WINTER WEATHER/MIX',
#        'FROST/FREEZE', 'ASTRONOMICAL HIGH TIDE', 'HEAVY SURF/HIGH SURF',
#        'TROPICAL DEPRESSION', 'LAKE-EFFECT SNOW', 'MARINE HIGH WIND',
#        'TSUNAMI', 'STORM SURGE/TIDE', 'COLD/WIND CHILL', 'LAKESHORE FLOOD',
#        'MARINE THUNDERSTORM WIND', 'MARINE STRONG WIND',
#        'ASTRONOMICAL LOW TIDE', 'DENSE SMOKE', 'MARINE HAIL',
#        'FREEZING FOG'], dtype=object)

# %%
len(df1.EVTYPE.unique())
# Out:
# 483

# %%
# Out:
# (254319, 7)
